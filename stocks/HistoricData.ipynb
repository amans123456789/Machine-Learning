# %%
# conda install git
# !pip install nsepy

# %%
# !pip install mplfinance

# %%
# !pip install --upgrade git+https://github.com/StreamAlpha/pynse.git

# %%
# !pip install ta-lib
# Out:
# ...
#   Running setup.py clean for ta-lib
# Failed to build ta-lib
# ...
#     Running setup.py install for ta-lib: started
#     Running setup.py install for ta-lib: finished with status 'error'
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\Aman\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Aman\\AppData\\Local\\Temp\\pip-install-tdmmjs70\\ta-lib_e66d5573cd9742d98ec7462abcfc628e\\setup.py'"'"'; __file__='"'"'C:\\Users\\Aman\\AppData\\Local\\Temp\\pip-install-tdmmjs70\\ta-lib_e66d5573cd9742d98ec7462abcfc628e\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\Aman\AppData\Local\Temp\pip-wheel-j4z67srf'
# ...

# %%
from pynse import *
import datetime
import logging
import talib

logging.basicConfig(level=logging.DEBUG)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16072/4159354471.py in <module>
#       2 import datetime
#       3 import logging
# ----> 4 import talib
#       5
#       6 logging.basicConfig(level=logging.DEBUG)
#
# ModuleNotFoundError: No module named 'talib'

# %%
nse=Nse()
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# DEBUG:pynse.core:First run.
# Creating folders and downloading symbol files
# DEBUG:pynse.core:copying symbol list for All
# DEBUG:pynse.core:copying symbol list for FnO
# DEBUG:pynse.core:copying symbol list for Nifty50
# DEBUG:pynse.core:copying symbol list for NiftyNext50
# DEBUG:pynse.core:copying symbol list for Nifty100
# DEBUG:pynse.core:copying symbol list for Nifty200
# DEBUG:pynse.core:copying symbol list for Nifty500
# DEBUG:pynse.core:copying symbol list for NiftyMidcap50
# DEBUG:pynse.core:copying symbol list for NiftyMidcap100
# DEBUG:pynse.core:copying symbol list for NiftySmlcap100
# DEBUG:pynse.core:copying symbol list for NiftyMidcap150
# DEBUG:pynse.core:copying symbol list for NiftySmlcap50
# DEBUG:pynse.core:copying symbol list for NiftySmlcap250
# DEBUG:pynse.core:copying symbol list for NiftyMidsml400
# DEBUG:pynse.core:copying symbol list for NiftyBank
# DEBUG:pynse.core:copying symbol list for NiftyAuto
# ...

# %%
nse.market_status()
# Out:
# INFO:pynse.core:downloading market status
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET / HTTP/1.1" 200 40090
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET /api/marketStatus HTTP/1.1" 200 221
# {'marketState': [{'market': 'Capital Market',
#    'marketStatus': 'Close',
#    'tradeDate': '31-Jan-2022',
#    'index': 'NIFTY 50',
#    'last': 17101.95,
#    'variation': -8.200000000000728,
#    'percentChange': -0.05,
#    'marketStatusMessage': 'Market is Closed'},
#   {'market': 'Currency',
#    'marketStatus': 'Close',
#    'tradeDate': '31-Jan-2022',
#    'index': '',
#    'last': '',
#    'variation': '',
#    'percentChange': '',
#    'marketStatusMessage': 'Market is Closed'},
#   {'market': 'Commodity',
#    'marketStatus': 'Close',
#    'tradeDate': '31-Jan-2022',
#    'index': '',
#    'last': '',
#    'variation': '',
#    'percentChange': '',
# ...

# %%
nse.info('SBIN')
# Out:
# INFO:pynse.core:downloading symbol info for SBIN
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET / HTTP/1.1" 200 40088
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET /api/equity-meta-info?symbol=SBIN HTTP/1.1" 200 209
# {'symbol': 'SBIN',
#  'companyName': 'State Bank of India',
#  'industry': 'BANKS',
#  'activeSeries': ['EQ'],
#  'debtSeries': [],
#  'tempSuspendedSeries': ['IL', 'N1', 'N2', 'N3', 'N4', 'N5', 'N6'],
#  'isFNOSec': True,
#  'isCASec': False,
#  'isSLBSec': True,
#  'isDebtSec': False,
#  'isSuspended': False,
#  'isETFSec': False,
#  'isDelisted': False,
#  'isin': 'INE062A08066'}

# %%
nse.get_quote('RELIANCE')
# Out:
# INFO:pynse.core:downloading quote for RELIANCE EQ
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET / HTTP/1.1" 200 40092
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET /api/quote-equity?symbol=RELIANCE HTTP/1.1" 200 941
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET / HTTP/1.1" 200 40088
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET /api/quote-equity?symbol=RELIANCE&section=trade_info HTTP/1.1" 200 404
# {'lastPrice': 2336,
#  'change': -2.099999999999909,
#  'pChange': -0.08981651768529615,
#  'previousClose': 2338.1,
#  'open': 2365,
#  'close': 2335.85,
#  'vwap': 2347.93,
#  'lowerCP': '2104.30',
#  'upperCP': '2571.90',
#  'pPriceBand': 'No Band',
#  'basePrice': 2338.1,
# ...

# %%
nse.bhavcopy()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3812/2820645626.py in <module>
# ----> 1 nse.bhavcopy()
#
# NameError: name 'nse' is not defined

# %%
import datetime
infy_data = nse.get_hist('infy',datetime.date(2020,1,1),datetime.date(2022,1,29))
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET / HTTP/1.1" 200 40086
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET /api/historical/cm/equity?symbol=INFY&series=%5B%22EQ%22%5D&from=01-01-2020&to=25-04-2021&csv=true HTTP/1.1" 200 14347
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET / HTTP/1.1" 200 40083
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET /api/historical/cm/equity?symbol=INFY&series=%5B%22EQ%22%5D&from=26-04-2021&to=29-01-2022&csv=true HTTP/1.1" 200 8747

# %%
import mplfinance as mpf
mpf.plot(infy_data.head(50), type ='candle', style ='yahoo', volume = True)
# Out:
# DEBUG:matplotlib:matplotlib data path: C:\Users\Aman\anaconda3\lib\site-packages\matplotlib\mpl-data
# DEBUG:matplotlib:CONFIGDIR=C:\Users\Aman\.matplotlib
# DEBUG:matplotlib:matplotlib version 3.4.3
# DEBUG:matplotlib:interactive is False
# DEBUG:matplotlib:platform is win32
# ...

# %%
nse.get_indices(IndexSymbol.NiftyBank)
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET / HTTP/1.1" 200 40089
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET /api/allIndices HTTP/1.1" 200 8596
#                           key       index     last  variation  percentChange  \
# indexSymbol
# NIFTY BANK   SECTORAL INDICES  NIFTY BANK  37689.4     -292.7          -0.77
#
#                 open     high      low  previousClose  yearHigh  ...  \
# indexSymbol                                                      ...
# NIFTY BANK   38246.6  38421.7  37581.5        37982.1   41829.6  ...
#
#              advances unchanged perChange365d  date365dAgo   date30dAgo  \
# indexSymbol
# NIFTY BANK          3         1         24.15  28-Jan-2021  29-Dec-2021
#
#             perChange30d previousDay oneWeekAgo oneMonthAgo oneYearAgo
# indexSymbol
# NIFTY BANK          7.54     37982.1    37574.3     35045.4    30358.3
#
# ...

# %%
nse.top_gainers(IndexSymbol.Nifty50, length=5)
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET / HTTP/1.1" 200 40091
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET /api/equity-stockIndices?index=NIFTY%2050 HTTP/1.1" 200 9460
#             priority     identifier   open  dayHigh  dayLow  lastPrice  \
# symbol
# NTPC               0        NTPCEQN  140.0   144.00  138.00     140.25
# UPL                0         UPLEQN  778.0   806.50  777.55     791.10
# SUNPHARMA          0   SUNPHARMAEQN  816.0   842.90  812.10     829.45
# TATACONSUM         0  TATACONSUMEQN  706.5   729.90  706.50     718.50
# INDUSINDBK         0  INDUSINDBKEQN  897.0   925.75  895.00     903.70
#
#             previousClose  change  pChange          ffmc  totalTradedVolume  \
# symbol
# NTPC               135.00    5.25     3.89  6.659040e+11           34009553
# UPL                771.95   19.15     2.48  4.347266e+11            4007799
# ...

# %%
nse.update_symbol_list()
# Out:
# DEBUG:pynse.core:downloading symbol list for All
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET / HTTP/1.1" 200 40095
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): archives.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://archives.nseindia.com:443 "GET /products/content/sec_bhavdata_full_08102020.csv HTTP/1.1" 200 None
# INFO:pynse.core:symbol list saved for IndexSymbol.All
# DEBUG:pynse.core:downloading symbol list for FnO
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET / HTTP/1.1" 200 40090
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET /api/master-quote HTTP/1.1" 200 927
# INFO:pynse.core:symbol list saved for IndexSymbol.FnO
# DEBUG:pynse.core:downloading symbol list for Nifty50
# ...

# %%
nse.clear_data()
# Out:
# Delete 'C:\Users\Aman\.pynse/' and its content, are you sure?? y/nn
# skipped

# %%
from nsepy import get_index_pe_history
nifty_pe = get_index_pe_history(symbol="NIFTY",
                                start=datetime.date(2015,1,1),
                                end=datetime.date(2015,1,10))
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www1.nseindia.com:80
# DEBUG:urllib3.connectionpool:http://www1.nseindia.com:80 "GET /products/dynaContent/equities/indices/historical_pepb.jsp?yield1=undefined&yield2=undefined&yield3=undefined&yield4=all&indexName=NIFTY+50&fromDate=01-01-2015&toDate=10-01-2015 HTTP/1.1" 302 0
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www1.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www1.nseindia.com:443 "GET /products/dynaContent/equities/indices/historical_pepb.jsp?yield1=undefined&yield2=undefined&yield3=undefined&yield4=all&indexName=NIFTY+50&fromDate=01-01-2015&toDate=10-01-2015 HTTP/1.1" 200 719

# %%
nifty_pe
# Out:
#               P/E   P/B  Div Yield
# Date
# 2015-01-01  21.16  3.49       1.27
# 2015-01-02  21.45  3.54       1.26
# 2015-01-05  21.40  3.53       1.26
# 2015-01-06  20.76  3.42       1.30
# 2015-01-07  20.70  3.41       1.30
# 2015-01-08  21.04  3.47       1.28
# 2015-01-09  21.16  3.49       1.27
